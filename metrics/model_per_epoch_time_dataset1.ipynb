#   inflating: dataset_1/bacterial spot/Bs27_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs27_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs28.JPG
#   inflating: dataset_1/bacterial spot/Bs28_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs28_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs28_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs28_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs28_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs29.JPG
#   inflating: dataset_1/bacterial spot/Bs29_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs29_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs29_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs29_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs29_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs29_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs29_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs3.JPG
#   inflating: dataset_1/bacterial spot/Bs3_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs3_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs3_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs3_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs3_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs3_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs30.JPG
#   inflating: dataset_1/bacterial spot/Bs30_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs30_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs30_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs30_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs30_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs31_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs31_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs31_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs31_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs31_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs32.JPG
#   inflating: dataset_1/bacterial spot/Bs32_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs32_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs32_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs32_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs32_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs32_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs32_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs33_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs33_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs33_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs33_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs34.JPG
#   inflating: dataset_1/bacterial spot/Bs34_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs34_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs82_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs82_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs82_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs82_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs83.JPG
#   inflating: dataset_1/bacterial spot/Bs83_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs83_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs83_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs83_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs84.JPG
#   inflating: dataset_1/bacterial spot/Bs84_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs84_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs84_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs84_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs84_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs84_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs85.JPG
#   inflating: dataset_1/bacterial spot/Bs85_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs85_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs85_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs85_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs86.JPG
#   inflating: dataset_1/bacterial spot/Bs86_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs86_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs86_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs86_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs86_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs86_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs86_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs87.JPG
#   inflating: dataset_1/bacterial spot/Bs87_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs87_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs87_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs87_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs87_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs87_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs88.JPG
#   inflating: dataset_1/bacterial spot/Bs88_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs88_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs88_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs88_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs88_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs88_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs89.JPG
#   inflating: dataset_1/bacterial spot/Bs89_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs89_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs89_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs89_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs89_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs96_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs97.JPG
#   inflating: dataset_1/bacterial spot/Bs97_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs97_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs97_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs97_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs98.JPG
#   inflating: dataset_1/bacterial spot/Bs98_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs98_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs98_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs98_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs98_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs98_mirror_vertical.jpg
#   inflating: dataset_1/bacterial spot/Bs99_change_180.jpg
#   inflating: dataset_1/bacterial spot/Bs99_change_270.jpg
#   inflating: dataset_1/bacterial spot/Bs99_change_90.jpg
#   inflating: dataset_1/bacterial spot/Bs99_hight.jpg
#   inflating: dataset_1/bacterial spot/Bs99_lower.jpg
#   inflating: dataset_1/bacterial spot/Bs99_mirror.jpg
#   inflating: dataset_1/bacterial spot/Bs99_mirror_vertical.jpg
#    creating: dataset_1/healthy/
#   inflating: dataset_1/healthy/h1.jpg
#   inflating: dataset_1/healthy/h1_change_180.jpg
#   inflating: dataset_1/healthy/h1_change_90.jpg
#   inflating: dataset_1/healthy/h1_hight.jpg
#   inflating: dataset_1/healthy/h1_lower.jpg
#   inflating: dataset_1/healthy/h1_mirror.jpg
#   inflating: dataset_1/healthy/h1_mirror_vertical.jpg
#   inflating: dataset_1/healthy/h10.jpg
#   inflating: dataset_1/healthy/h10_change_180.jpg
#   inflating: dataset_1/healthy/h10_change_270.jpg
#   inflating: dataset_1/healthy/h10_change_90.jpg
#   inflating: dataset_1/healthy/h10_hight.jpg
#   inflating: dataset_1/healthy/h10_lower.jpg
#   inflating: dataset_1/healthy/h10_mirror.jpg
#   inflating: dataset_1/healthy/h10_mirror_vertical.jpg
#   inflating: dataset_1/healthy/h100.jpg
#   inflating: dataset_1/healthy/h100_change_180.jpg
#   inflating: dataset_1/healthy/h100_change_90.jpg
#   inflating: dataset_1/healthy/h100_hight.jpg
#   inflating: dataset_1/healthy/h100_lower.jpg
#   inflating: dataset_1/healthy/h100_mirror_vertical.jpg
#   inflating: dataset_1/healthy/h101.jpg
#   inflating: dataset_1/healthy/h101_change_180.jpg
#   inflating: dataset_1/healthy/h101_change_270.jpg
#   inflating: dataset_1/healthy/h101_change_90.jpg
#   inflating: dataset_1/healthy/h101_hight.jpg
#   inflating: dataset_1/healthy/h101_mirror.jpg
#   inflating: dataset_1/healthy/h102_change_180.jpg
#   inflating: dataset_1/healthy/h102_change_270.jpg
#   inflating: dataset_1/healthy/h102_hight.jpg
#   inflating: dataset_1/healthy/h102_lower.jpg
#   inflating: dataset_1/healthy/h102_mirror.jpg
#   inflating: dataset_1/healthy/h102_mirror_vertical.jpg
#   inflating: dataset_1/healthy/h103.jpg
#   inflating: dataset_1/late blight/Lb72_mirror.jpg
#   inflating: dataset_1/late blight/Lb72_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb73.JPG
#   inflating: dataset_1/late blight/Lb73_change_180.jpg
#   inflating: dataset_1/late blight/Lb73_hight.jpg
#   inflating: dataset_1/late blight/Lb73_lower.jpg
#   inflating: dataset_1/late blight/Lb74.JPG
#   inflating: dataset_1/late blight/Lb74_change_180.jpg
#   inflating: dataset_1/late blight/Lb74_change_270.jpg
#   inflating: dataset_1/late blight/Lb74_change_90.jpg
#   inflating: dataset_1/late blight/Lb74_hight.jpg
#   inflating: dataset_1/late blight/Lb74_lower.jpg
#   inflating: dataset_1/late blight/Lb74_mirror.jpg
#   inflating: dataset_1/late blight/Lb74_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb75.JPG
#   inflating: dataset_1/late blight/Lb75_change_180.jpg
#   inflating: dataset_1/late blight/Lb75_change_270.jpg
#   inflating: dataset_1/late blight/Lb75_change_90.jpg
#   inflating: dataset_1/late blight/Lb75_hight.jpg
#   inflating: dataset_1/late blight/Lb75_lower.jpg
#   inflating: dataset_1/late blight/Lb75_mirror.jpg
#   inflating: dataset_1/late blight/Lb76.JPG
#   inflating: dataset_1/late blight/Lb76_change_180.jpg
#   inflating: dataset_1/late blight/Lb76_change_90.jpg
#   inflating: dataset_1/late blight/Lb76_hight.jpg
#   inflating: dataset_1/late blight/Lb76_lower.jpg
#   inflating: dataset_1/late blight/Lb76_mirror.jpg
#   inflating: dataset_1/late blight/Lb77.JPG
#   inflating: dataset_1/late blight/Lb77_change_180.jpg
#   inflating: dataset_1/late blight/Lb77_change_270.jpg
#   inflating: dataset_1/late blight/Lb77_change_90.jpg
#   inflating: dataset_1/late blight/Lb77_lower.jpg
#   inflating: dataset_1/late blight/Lb77_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb78.JPG
#   inflating: dataset_1/late blight/Lb78_change_180.jpg
#   inflating: dataset_1/late blight/Lb78_change_270.jpg
#   inflating: dataset_1/late blight/Lb78_change_90.jpg
#   inflating: dataset_1/late blight/Lb78_mirror.jpg
#   inflating: dataset_1/late blight/Lb78_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb79_change_180.jpg
#   inflating: dataset_1/late blight/Lb79_change_270.jpg
#   inflating: dataset_1/late blight/Lb79_lower.jpg
#   inflating: dataset_1/late blight/Lb79_mirror.jpg
#   inflating: dataset_1/late blight/Lb79_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb8_change_180.jpg
#   inflating: dataset_1/late blight/Lb8_change_270.jpg
#   inflating: dataset_1/late blight/Lb8_lower.jpg
#   inflating: dataset_1/late blight/Lb8_mirror.jpg
#   inflating: dataset_1/late blight/Lb8_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb80.JPG
#   inflating: dataset_1/late blight/Lb80_change_180.jpg
#   inflating: dataset_1/late blight/Lb80_change_270.jpg
#   inflating: dataset_1/late blight/Lb80_change_90.jpg
#   inflating: dataset_1/late blight/Lb80_lower.jpg
#   inflating: dataset_1/late blight/Lb80_mirror.jpg
#   inflating: dataset_1/late blight/Lb89_change_270.jpg
#   inflating: dataset_1/late blight/Lb89_change_90.jpg
#   inflating: dataset_1/late blight/Lb89_hight.jpg
#   inflating: dataset_1/late blight/Lb89_lower.jpg
#   inflating: dataset_1/late blight/Lb89_mirror.jpg
#   inflating: dataset_1/late blight/Lb89_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb9_change_180.jpg
#   inflating: dataset_1/late blight/Lb9_change_270.jpg
#   inflating: dataset_1/late blight/Lb9_change_90.jpg
#   inflating: dataset_1/late blight/Lb9_hight.jpg
#   inflating: dataset_1/late blight/Lb9_lower.jpg
#   inflating: dataset_1/late blight/Lb9_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb90.JPG
#   inflating: dataset_1/late blight/Lb90_change_270.jpg
#   inflating: dataset_1/late blight/Lb90_change_90.jpg
#   inflating: dataset_1/late blight/Lb90_hight.jpg
#   inflating: dataset_1/late blight/Lb90_lower.jpg
#   inflating: dataset_1/late blight/Lb90_mirror.jpg
#   inflating: dataset_1/late blight/Lb90_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb91.JPG
#   inflating: dataset_1/late blight/Lb91_change_180.jpg
#   inflating: dataset_1/late blight/Lb91_change_270.jpg
#   inflating: dataset_1/late blight/Lb91_change_90.jpg
#   inflating: dataset_1/late blight/Lb91_hight.jpg
#   inflating: dataset_1/late blight/Lb91_lower.jpg
#   inflating: dataset_1/late blight/Lb91_mirror.jpg
#   inflating: dataset_1/late blight/Lb91_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb92.JPG
#   inflating: dataset_1/late blight/Lb92_change_180.jpg
#   inflating: dataset_1/late blight/Lb92_change_270.jpg
#   inflating: dataset_1/late blight/Lb92_hight.jpg
#   inflating: dataset_1/late blight/Lb92_lower.jpg
#   inflating: dataset_1/late blight/Lb92_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb93.JPG
#   inflating: dataset_1/late blight/Lb93_change_180.jpg
#   inflating: dataset_1/late blight/Lb93_change_270.jpg
#   inflating: dataset_1/late blight/Lb93_hight.jpg
#   inflating: dataset_1/late blight/Lb93_lower.jpg
#   inflating: dataset_1/late blight/Lb93_mirror.jpg
#   inflating: dataset_1/late blight/Lb93_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb94.JPG
#   inflating: dataset_1/late blight/Lb94_change_180.jpg
#   inflating: dataset_1/late blight/Lb94_change_270.jpg
#   inflating: dataset_1/late blight/Lb94_change_90.jpg
#   inflating: dataset_1/late blight/Lb94_hight.jpg
#   inflating: dataset_1/late blight/Lb94_lower.jpg
#   inflating: dataset_1/late blight/Lb94_mirror.jpg
#   inflating: dataset_1/late blight/Lb94_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb95.JPG
#   inflating: dataset_1/late blight/Lb95_change_180.jpg
#   inflating: dataset_1/late blight/Lb95_change_270.jpg
#   inflating: dataset_1/late blight/Lb95_change_90.jpg
#   inflating: dataset_1/late blight/Lb95_hight.jpg
#   inflating: dataset_1/late blight/Lb95_lower.jpg
#   inflating: dataset_1/late blight/Lb95_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb96_change_180.jpg
#   inflating: dataset_1/late blight/Lb96_change_270.jpg
#   inflating: dataset_1/late blight/Lb96_change_90.jpg
#   inflating: dataset_1/late blight/Lb96_hight.jpg
#   inflating: dataset_1/late blight/Lb96_lower.jpg
#   inflating: dataset_1/late blight/Lb96_mirror.jpg
#   inflating: dataset_1/late blight/Lb96_mirror_vertical.jpg
#   inflating: dataset_1/late blight/Lb97.JPG
#   inflating: dataset_1/late blight/Lb97_change_180.jpg
#   inflating: dataset_1/late blight/Lb97_change_90.jpg
#   inflating: dataset_1/late blight/Lb97_hight.jpg
#   inflating: dataset_1/late blight/Lb97_mirror.jpg
#   inflating: dataset_1/late blight/Lb98.JPG
#   inflating: dataset_1/late blight/Lb98_change_180.jpg
#   inflating: dataset_1/late blight/Lb98_change_270.jpg
#   inflating: dataset_1/late blight/Lb98_change_90.jpg
#   inflating: dataset_1/late blight/Lb98_hight.jpg
#   inflating: dataset_1/late blight/Lb98_mirror_vertical.jpg

# %%
DATASET_TYPE = 'dataset_1'

# %%
import torch
import torch.nn as nn
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

import torchvision
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.models import resnet18, mobilenet_v2, vgg16

import time

# %%
# splitting the dataset into specific folders for train, validate and test
# %pip install split-folders

import splitfolders

source_folder = f'{DATASET_TYPE}'
target_folder = f'{DATASET_TYPE}_splitted'

train_ratio = .7
val_ratio = .15
test_ratio = .15

splitfolders.ratio(source_folder, output=target_folder, seed=1337, ratio=(train_ratio, val_ratio, test_ratio), group_prefix=None, move=False)
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 2009 files [00:00, 4900.32 files/s]

# %%
# applying data prepocessing and loading dataset
train_dataset_tranform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_dataset_tranform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = ImageFolder(f"{DATASET_TYPE}_splitted/train", transform=train_dataset_tranform)
train_length = len(train_dataset)

validate_dataset = ImageFolder(f"{DATASET_TYPE}_splitted/val", transform=test_dataset_tranform)
validate_length = len(validate_dataset)

test_dataset = ImageFolder(f"{DATASET_TYPE}_splitted/test", transform=test_dataset_tranform)
test_dataset_length = len(test_dataset)

dataset_classes = train_dataset.classes
print(dataset_classes)
# Out:
# ['bacterial spot', 'healthy', 'late blight']

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
validate_loader = DataLoader(validate_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# setting up the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# modifying architecture output classes
class ResNet18(nn.Module):
  def __init__(self, num_of_classes):
    super(ResNet18, self).__init__()
    self.model = resnet18(weights=None)
    features = self.model.fc.in_features
    self.model.fc = nn.Linear(features, num_of_classes)

  def forward(self, x):
    x = self.model(x)
    return x

# %%
# modifying architecture output classes
class MobileNetV2(nn.Module):
  def __init__(self, num_of_classes):
    super(MobileNetV2, self).__init__()
    self.model = mobilenet_v2(weights=None)
    features = self.model.classifier[-1].in_features
    self.model.classifier[-1] = nn.Linear(features, num_of_classes)

  def forward(self, x):
    x = self.model(x)
    return x

# %%
# modifying architecture output classes
class VGG16(nn.Module):
  def __init__(self, num_of_classes):
    super(VGG16, self).__init__()
    self.model = vgg16(weights=None)
    features = self.model.classifier[-1].in_features
    self.model.classifier[-1] = nn.Linear(features, num_of_classes)

  def forward(self, x):
    x = self.model(x)
    return x

# %%
# defining model, optimizer, architecture
learning_rate = 0.001
epochs = 1

# %%
model_1 = ResNet18(num_of_classes=len(dataset_classes))
model_1 = model_1.to(device)
optimizer = Adam(model_1.parameters(), lr=learning_rate)
loss_function = CrossEntropyLoss()

print(model_1)
# Out:
# ResNet18(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
train_losses = []
train_accuracies = []
validate_losses = []
validate_accuracies = []

start_time = time.time()

for epoch in range(epochs):

  print(f"epoch number ---> {epoch + 1} ")

  model_1.train()
  train_batch_loss = 0.0
  train_correct_predictions = 0
  train_samples = 0
  for xtrain, ytrain in train_loader:

    optimizer.zero_grad()

    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    train_prob = model_1(xtrain)

    # calculating batch accuracy
    _, train_prediction = torch.max(train_prob, 1)
    train_samples += ytrain.size(0)
    train_correct_predictions += (train_prediction == ytrain).sum().item()

    loss = loss_function(train_prob, ytrain)
    loss.backward()
    optimizer.step()

    # calculating batch loss
    train_batch_loss += loss.item()

  # calculating train loss for epoch
  train_loss = train_batch_loss / len(train_loader)
  train_losses.append(train_loss)

  # calculating train accuracy for epoch
  train_accuracy = 100 * (train_correct_predictions / train_samples)
  train_accuracies.append(train_accuracy)
  print("training loss: {:.4f}  training accuracy: {:.2f} %".format(train_loss, train_accuracy))

  validate_batch_loss = 0.0
  validate_correct_predictions = 0
  validate_samples = 0
  model_1.eval()
  with torch.no_grad():
    for xvalidate, yvalidate in validate_loader:

      optimizer.zero_grad()

      xvalidate = xvalidate.to(device)
      yvalidate = yvalidate.to(device)
      validate_prob = model_1(xvalidate)

      #calculating batch accuracy
      _, validate_prediction = torch.max(validate_prob, 1)
      validate_samples += yvalidate.size(0)
      validate_correct_predictions += (validate_prediction == yvalidate).sum().item()

      loss = loss_function(validate_prob, yvalidate)

      #calculating batch loss
      validate_batch_loss += loss.item()

  # calculating validate loss for epoch
  validate_loss = validate_batch_loss / len(validate_loader)
  validate_losses.append(validate_loss)

  # calculating validate accuracy for epoch
  validate_accuracy = 100 * (validate_correct_predictions / validate_samples)
  validate_accuracies.append(validate_accuracy)
  print("validation loss: {:.4f}  validation accuracy: {:.2f} %".format(validate_loss, validate_accuracy))

end_time = time.time()
epoch_time = end_time - start_time

print("Wall Clock Time for One Epoch RestNet18:", epoch_time, "seconds")
# Out:
# epoch number ---> 1
# training loss: 0.9899  training accuracy: 57.76 %
# validation loss: 1.1268  validation accuracy: 57.67 %
# Wall Clock Time for One Epoch RestNet18: 20.239220142364502 seconds

# %%
model_2 = MobileNetV2(num_of_classes=len(dataset_classes))
model_2 = model_2.to(device)
optimizer = Adam(model_2.parameters(), lr=learning_rate)
loss_function = CrossEntropyLoss()

print(model_2)
# Out:
# MobileNetV2(
#   (model): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=False)
#       (1): Linear(in_features=1280, out_features=3, bias=True)
#     )
#   )
# )

# %%
train_losses = []
train_accuracies = []
validate_losses = []
validate_accuracies = []

start_time = time.time()

for epoch in range(epochs):

  print(f"epoch number ---> {epoch + 1} ")

  model_2.train()
  train_batch_loss = 0.0
  train_correct_predictions = 0
  train_samples = 0
  for xtrain, ytrain in train_loader:

    optimizer.zero_grad()

    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    train_prob = model_2(xtrain)

    # calculating batch accuracy
    _, train_prediction = torch.max(train_prob, 1)
    train_samples += ytrain.size(0)
    train_correct_predictions += (train_prediction == ytrain).sum().item()

    loss = loss_function(train_prob, ytrain)
    loss.backward()
    optimizer.step()

    # calculating batch loss
    train_batch_loss += loss.item()

  # calculating train loss for epoch
  train_loss = train_batch_loss / len(train_loader)
  train_losses.append(train_loss)

  # calculating train accuracy for epoch
  train_accuracy = 100 * (train_correct_predictions / train_samples)
  train_accuracies.append(train_accuracy)
  print("training loss: {:.4f}  training accuracy: {:.2f} %".format(train_loss, train_accuracy))

  validate_batch_loss = 0.0
  validate_correct_predictions = 0
  validate_samples = 0
  model_2.eval()
  with torch.no_grad():
    for xvalidate, yvalidate in validate_loader:

      optimizer.zero_grad()

      xvalidate = xvalidate.to(device)
      yvalidate = yvalidate.to(device)
      validate_prob = model_2(xvalidate)

      #calculating batch accuracy
      _, validate_prediction = torch.max(validate_prob, 1)
      validate_samples += yvalidate.size(0)
      validate_correct_predictions += (validate_prediction == yvalidate).sum().item()

      loss = loss_function(validate_prob, yvalidate)

      #calculating batch loss
      validate_batch_loss += loss.item()

  # calculating validate loss for epoch
  validate_loss = validate_batch_loss / len(validate_loader)
  validate_losses.append(validate_loss)

  # calculating validate accuracy for epoch
  validate_accuracy = 100 * (validate_correct_predictions / validate_samples)
  validate_accuracies.append(validate_accuracy)
  print("validation loss: {:.4f}  validation accuracy: {:.2f} %".format(validate_loss, validate_accuracy))

end_time = time.time()
epoch_time = end_time - start_time

print("Wall Clock Time for One Epoch MobileNetV2:", epoch_time, "seconds")
# Out:
# epoch number ---> 1
# training loss: 0.9070  training accuracy: 53.28 %
# validation loss: 1.7064  validation accuracy: 35.00 %
# Wall Clock Time for One Epoch MobileNetV2: 18.982508182525635 seconds

# %%
model_3 = VGG16(num_of_classes=len(dataset_classes))
model_3 = model_3.to(device)
optimizer = Adam(model_3.parameters(), lr=learning_rate)
loss_function = CrossEntropyLoss()

print(model_3)
# Out:
# VGG16(
#   (model): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#     (classifier): Sequential(
#       (0): Linear(in_features=25088, out_features=4096, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=4096, out_features=4096, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=4096, out_features=3, bias=True)
#     )
#   )
# )

# %%
train_losses = []
train_accuracies = []
validate_losses = []
validate_accuracies = []

start_time = time.time()

for epoch in range(epochs):

  print(f"epoch number ---> {epoch + 1} ")

  model_3.train()
  train_batch_loss = 0.0
  train_correct_predictions = 0
  train_samples = 0
  for xtrain, ytrain in train_loader:

    optimizer.zero_grad()

    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    train_prob = model_3(xtrain)

    # calculating batch accuracy
    _, train_prediction = torch.max(train_prob, 1)
    train_samples += ytrain.size(0)
    train_correct_predictions += (train_prediction == ytrain).sum().item()

    loss = loss_function(train_prob, ytrain)
    loss.backward()
    optimizer.step()

    # calculating batch loss
    train_batch_loss += loss.item()

  # calculating train loss for epoch
  train_loss = train_batch_loss / len(train_loader)
  train_losses.append(train_loss)

  # calculating train accuracy for epoch
  train_accuracy = 100 * (train_correct_predictions / train_samples)
  train_accuracies.append(train_accuracy)
  print("training loss: {:.4f}  training accuracy: {:.2f} %".format(train_loss, train_accuracy))

  validate_batch_loss = 0.0
  validate_correct_predictions = 0
  validate_samples = 0
  model_3.eval()
  with torch.no_grad():
    for xvalidate, yvalidate in validate_loader:

      optimizer.zero_grad()

      xvalidate = xvalidate.to(device)
      yvalidate = yvalidate.to(device)
      validate_prob = model_3(xvalidate)

      #calculating batch accuracy
      _, validate_prediction = torch.max(validate_prob, 1)
      validate_samples += yvalidate.size(0)
      validate_correct_predictions += (validate_prediction == yvalidate).sum().item()

      loss = loss_function(validate_prob, yvalidate)

      #calculating batch loss
      validate_batch_loss += loss.item()

  # calculating validate loss for epoch
  validate_loss = validate_batch_loss / len(validate_loader)
  validate_losses.append(validate_loss)

  # calculating validate accuracy for epoch
  validate_accuracy = 100 * (validate_correct_predictions / validate_samples)
  validate_accuracies.append(validate_accuracy)
  print("validation loss: {:.4f}  validation accuracy: {:.2f} %".format(validate_loss, validate_accuracy))

end_time = time.time()
epoch_time = end_time - start_time

print("Wall Clock Time for One Epoch Vgg16:", epoch_time, "seconds")
# Out:
# epoch number ---> 1
# training loss: 13.4855  training accuracy: 33.62 %
# validation loss: 1.2808  validation accuracy: 33.67 %
# Wall Clock Time for One Epoch Vgg16: 33.34986734390259 seconds
